# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import dabl

# %%
# importing dataset
df=pd.read_csv('Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.describe()
df.shape
# Out:
# (200, 5)

# %%
#get head of dataset
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# get tail
df.tail()
# Out:
#      CustomerID  Gender  Age  Annual_Income(k$)  Spending_Score(1-100)
# 195         196  Female   35                120                     79
# 196         197  Female   45                126                     28
# 197         198    Male   32                126                     74
# 198         199    Male   32                137                     18
# 199         200    Male   30                137                     83

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.columns=['CustomerID','Gender','Age','AnnualIncome(k$)','SpendingScore(1-100)']
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'AnnualIncome(k$)',
#        'SpendingScore(1-100)'],
#       dtype='object')

# %%
df
# Out:
#      CustomerID  Gender  Age  AnnualIncome(k$)  SpendingScore(1-100)
# 0             1    Male   19                15                    39
# 1             2    Male   21                15                    81
# 2             3  Female   20                16                     6
# 3             4  Female   23                16                    77
# 4             5  Female   31                17                    40
# ..          ...     ...  ...               ...                   ...
# 195         196  Female   35               120                    79
# 196         197  Female   45               126                    28
# 197         198    Male   32               126                    74
# 198         199    Male   32               137                    18
# 199         200    Male   30               137                    83
#
# [200 rows x 5 columns]

# %%
#check sample of data
df.sample(4)
# Out:
#      CustomerID  Gender  Age  AnnualIncome(k$)  SpendingScore(1-100)
# 125         126  Female   31                70                    77
# 153         154  Female   38                78                    76
# 94           95  Female   32                60                    42
# 66           67  Female   43                48                    50

# %%
#get pairplot of data
sns.pairplot(df)
plt.show()

# %%
# correlation heat map of data
sns.heatmap(df.corr(),annot=True,cmap='hot')
plt.title("correlation heat map of data",fontsize=25)
plt.show()

# %%
# analyze data wrt spending score
dabl.plot(df,target_col='SpendingScore(1-100)')
# Out:
# Target looks like regression

# %%
# analyze annual income with datset

dabl.plot(df,target_col='AnnualIncome(k$)')
# Out:
# Target looks like regression

# %% [markdown]
# # Descriptive statistics

# %%
# describe data
df.describe()
# Out:
#        CustomerID         Age  AnnualIncome(k$)  SpendingScore(1-100)
# count  200.000000  200.000000        200.000000            200.000000
# mean   100.500000   38.850000         60.560000             50.200000
# std     57.879185   13.969007         26.264721             25.823522
# min      1.000000   18.000000         15.000000              1.000000
# 25%     50.750000   28.750000         41.500000             34.750000
# 50%    100.500000   36.000000         61.500000             50.000000
# 75%    150.250000   49.000000         78.000000             73.000000
# max    200.000000   70.000000        137.000000             99.000000

# %%
# describing categorical data
df.describe(include='object')
# Out:
#         Gender
# count      200
# unique       2
# top     Female
# freq       112

# %%
#check for null values
df.isnull().any().any()
# Out:
# False

# %% [markdown]
# # Data visualization

# %%
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize']=(10,3)

plt.subplot(1,2,1)
sns.set(style='whitegrid')
sns.distplot(df['AnnualIncome(k$)'])
plt.title("distribution of annaual income",fontsize=12)
plt.xlabel("range of annual income",fontsize=10)
plt.ylabel("count")


plt.subplot(1,2,2)
sns.set(style='whitegrid')
sns.distplot(df['Age'],color='red')
plt.title("distribution of age",fontsize=12)
plt.xlabel("range of age",fontsize=10)
plt.ylabel("count")
plt.show()

# %%
# visualize gender gap

labels=['female','male']
size=df['Gender'].value_counts()
colors=['lightgreen','lightblue']
explode=[0,0.001]

plt.rcParams['figure.figsize']=(9,9)
plt.pie(size,colors=colors,explode=explode,labels=labels,shadow=True,startangle=90,autopct='%.2f%%')
plt.title("gender gap",fontsize=20)
plt.axis('off')
plt.legend()
plt.show()

# %%
plt.rcParams['figure.figsize']=(15,8)
sns.countplot(df['Age'],palette='hsv')
plt.title("distribution of Age",fontsize=20)
plt.show()

# %%
# check distribution of annual income

plt.rcParams['figure.figsize']=(20,8)
sns.distplot(df['AnnualIncome(k$)'],color ='green')
plt.title("distribution of annual income",fontsize=20)
plt.show()

# %%
# distribution of spending score
plt.rcParams['figure.figsize']=(20,8)
sns.distplot(df['SpendingScore(1-100)'],color ='black')
plt.title("distribution of spending score",fontsize=20)
plt.show()

# %%
# genger vs spend score
plt.rcParams['figure.figsize']=(20,8)
sns.boxenplot(df['Gender'],df['SpendingScore(1-100)'],palette='Blues')
plt.title("Gender v/s Spending score",fontsize=16)
plt.show()

# %%
#gender vs annual income
plt.rcParams['figure.figsize']=(20,8)
sns.violinplot(df['Gender'],df['AnnualIncome(k$)'],palette='rainbow')
plt.title("Gender v/s Annual income",fontsize=16)
plt.show()

# %%
#gender vs age
plt.rcParams['figure.figsize']=(20,8)
sns.stripplot(df['Gender'],df['Age'],palette='Greens',size=10)
plt.title("Gender v/s Age",fontsize=16)
plt.show()

# %%
#annual income vs age and spending score
x=df['AnnualIncome(k$)']
y=df['Age']
z=df['SpendingScore(1-100)']

sns.lineplot(x,y,color='blue')
sns.lineplot(x,z,color='red')
plt.title("annaual income vs age and spending score",fontsize=12)
plt.show()

# %% [markdown]
#  # Cluster Analysis

# %%
#we want to form clusters of customers of similar behaviour for that lets select the columns
# spending score and annaual income

# avoid warnings
import warnings
warnings.filterwarnings('ignore')

#select spending score and annual income from data
x = df.loc[:,['SpendingScore(1-100)','AnnualIncome(k$)']].values
#check shape of x
print(x.shape)
# Out:
# (200, 2)

# %%
#check data ,to be used for cluster analysis

x_data=pd.DataFrame(x)
x_data.head()
#0- spending score 1<- annual income
# Out:
#     0   1
# 0  39  15
# 1  81  15
# 2   6  16
# 3  77  16
# 4  40  17

# %% [markdown]
# # Kmeans algorithm

# %% [markdown]
# elbow method to find no. of clusters

# %%
from sklearn.cluster import KMeans

wcss=[]
for i in range(1,11):
    km = KMeans(n_clusters=i,init = 'k-means++',max_iter=300,n_init=10,random_state=0)
    km.fit(x)
    wcss.append(km.inertia_)

plt.plot(range(1,11),wcss)
plt.title("The Elbow Method",fontsize=20)
plt.xlabel("No. of cluster")
plt.ylabel("wcss")
plt.show()

# %%
# Visualize the clusters

plt.style.use('fivethirtyeight')

km = KMeans(n_clusters=5,init='k-means++',max_iter=300,n_init=10,random_state=0)
y_means = km.fit_predict(x)

plt.scatter(x[y_means == 0,0],x[y_means == 0,1],s=100,c='green',label='wiser')
plt.scatter(x[y_means == 1,0],x[y_means == 1,1],s=100,c='yellow',label='general')
plt.scatter(x[y_means == 2,0],x[y_means == 2,1],s=100,c='red',label='target')
plt.scatter(x[y_means == 3,0],x[y_means == 3,1],s=100,c='magenta',label='spendthrift')
plt.scatter(x[y_means == 4,0],x[y_means == 4,1],s=100,c='orange',label='careful')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],s=50,c='blue',label='centroid')

plt.style.use('fivethirtyeight')
plt.title("k means clustering between annual income and spending score",fontsize=20)
plt.xlabel("annual income")
plt.ylabel("spending score")
plt.legend()
plt.grid()
plt.show()

# %%
# clustering b/w  age  and spending score

from sklearn.cluster import KMeans

wcss=[]
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init = 'k-means++',max_iter=300,n_init=10,random_state=0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
    
plt.rcParams['figure.figsize']=(15,5)
plt.plot(range(1,11),wcss)
plt.title("K means clustering (The Elbow Method)",fontsize=20)
plt.xlabel("Age")
plt.ylabel("count")
plt.grid()
plt.show()

# %%
kmeans = KMeans(n_clusters=4,init='k-means++',max_iter=300,n_init=10,random_state=0)
y_means = kmeans.fit_predict(x)

plt.rcParams['figure.figsize']=(10,20)

plt.scatter(x[y_means == 0,0],x[y_means == 0,1],s=100,c='green',label='usual customers')
plt.scatter(x[y_means == 1,0],x[y_means == 1,1],s=100,c='orange',label='priority cutomers')
plt.scatter(x[y_means == 2,0],x[y_means == 2,1],s=100,c='blue',label='target customers(young)')
plt.scatter(x[y_means == 3,0],x[y_means == 3,1],s=100,c='magenta',label='target customers(old)')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=200,c='red')

plt.style.use('fivethirtyeight')
plt.xlabel("Age")
plt.ylabel("Spending score(1-100)")
plt.legend()
plt.grid()
plt.show()
